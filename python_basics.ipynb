# %%
print("Welcome to Data Science")
# Out:
# Welcome to Data Science

# %%
x = 5
print("value of x:", x)
print(type(x))
# Out:
# value of x: 5
# <class 'int'>

# %%
name = "hafidz"
birthdayYear = 2006;
currentYear = 2025;
age = currentYear - birthdayYear
print("Name :", name, "with the age of", age, "as of year", currentYear)
# Out:
# Name : hafidz with the age of 19 as of year 2025
