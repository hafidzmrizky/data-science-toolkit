# %%
# !python --version
# Out:
# Python 3.12.12

# %%
x=3
print(x, type(x))
print(x*2)
print(x**2)

x+=1
print(x)
x*=2
print(x)
x**=2
print(x)
# Out:
# 3 <class 'int'>
# 6
# 9
# 4
# 8
# 64

# %%
y = 3.5
print(y, type(y))

print(x*y)
# Out:
# 3.5 <class 'float'>

# %%
t=True
print(t)
# Out:
# True

# %%
var1="Hello"
var2="Class"

print(var1, len(var1))
# Out:
# Hello 5

# %%
new_var = var1 + ' ' + var2
print(new_var, len(new_var))
# Out:
# Hello Class 11

# %%
another_var = '{} {} {}'.format(var1, var2, str(x))
print(another_var)
# Out:
# Hello Class 64

# %%
print(type('meow'))
list1 = [1,4,3]
list1.append('Science')
print(list1)
# Out:
# <class 'str'>
# [1, 4, 3, 'Science']

# %%
list1.pop(2)
print(list1)
# Out:
# [1, 4, 'Science']

# %%
numbers=list(range(6))
print(numbers)
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
list2 = [11, 1, 4, 3, 2]
list2[2:4] = [50,100]
print(list2[1:4])
# Out:
# [1, 50, 100]

# %%
animal_response={'cat': 'meow', 'dog': 'bark'}
print(animal_response['cat'])
animal_response['dog'] = 'guk guk'
print(animal_response['dog'])
print('cat' in animal_response)
del animal_response['cat']
print('cat' in animal_response)
# Out:
# meow
# guk guk
# True
# False
